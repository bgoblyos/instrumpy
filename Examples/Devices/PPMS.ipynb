# %%
# Libraries
import pyvisa                    # Communication (also install pyvisa-py or NI VISA)
import matplotlib.pyplot as plt  # Plots
import numpy as np               # Maths
import pandas as pd              # DataFrames
import time                      # Delays
from tqdm.notebook import tqdm   # Progress bars (use 'for i in tqdm(iter)')
import os                        # Used for determining platform
import sys                       # Used for local import setup
sys.path.append(r"../../")       # Used for local imports

# %%
from Utilities.SetupLogging import setupLogging
logger = setupLogging()

# %%
from Devices.QuantumDesign import PPMS

# %%
device = PPMS("127.0.0.1")

# %%
device.isSteady(temp=True)
# Out:
# False

# %%
device.getTemperature()
# Out:
# (272.6999999999938, 'Tracking')

# %%
device.setRotatorPosition(100)

# %%
device.getRotatorPosition()
# Out:
# (100.0, 'Transport stopped at set point')

# %%
device.setTemperature(250, 10, fast = True)

# %%
device.getTemperature()
# Out:
# (272.59999999999377, 'Stable')

# %%
device.setChamber("purge_seal")

# %%
device.getChamber()
# Out:
# 'Purged and Sealed'

# %%
device.setField(1, 1, driven = True, unit='T')

# %%
device.getFieldSetpoint()
# Out:
# (1.0, 1.0, 'linear', True)

# %%
device.getField()
# Out:
# (1.0, 'Stable')

# %%
device.waitFor(10, temp=True)
# Out:
# False

# %%
device.logger.error('testing')
# Out:
# ERROR	- instrumpy.PPMS - testing

# %%
logger.error('aaa')
# Out:
# ERROR	- instrumpy - aaa

# %%
device.setField
