# %%
# Libraries
import pyvisa                    # Communication (also install pyvisa-py or NI VISA)
import matplotlib.pyplot as plt  # Plots
import numpy as np               # Maths
import pandas as pd              # DataFrames
import time                      # Delays
from tqdm.notebook import tqdm   # Progress bars (use 'for i in tqdm(iter)')
import os                        # Used for determining platform
import sys                       # Used for local import setup
sys.path.append(r"../../")       # Used for local imports

# %%
from Utilities.SetupLogging import setupLogging
logger = setupLogging()

# %%
from Devices.Coherent import SapphireLP

# %%
rm = pyvisa.ResourceManager()
device = SapphireLP(rm, address='ASRL1::INSTR')

# %%
rm.list_resources()
# Out:
# ('USB0::0x1313::0x8078::P0017770::INSTR',
#  'USB0::0x05E6::0x2450::04085563::INSTR',
#  'ASRL3::INSTR',
#  'ASRL4::INSTR',
#  'ASRL6::INSTR',
#  'GPIB1::14::INSTR')

# %%
device.getID()
# Out:
# 'Sapphire-LP-527675'

# %%
device.minPower, device.maxPower
# Out:
# (10.0, 330.0)

# %%
err = None
try:
    device.power
except pyvisa.VisaIOError as e:
    err = e

err

# %%
type(err)
# Out:
# NoneType

# %%
device.maxPower
# Out:
# 330.0

# %%
device.power=330

# %%
device.power
# Out:
# 0.588

# %%
device.flushBuffer()

# %%
del device

# %%
device.off()

# %%
device.on()
