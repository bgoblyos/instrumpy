# %%
# Libraries
import pyvisa                    # Communication (also install pyvisa-py or NI VISA)
import matplotlib.pyplot as plt  # Plots
import numpy as np               # Maths
import pandas as pd              # DataFrames
import time                      # Delays
from tqdm.notebook import tqdm   # Progress bars (use 'for i in tqdm(iter)')
import os                        # Used for determining platform
import sys                       # Used for local import setup
sys.path.append(r"../../")       # Used for local imports

# %%
from Utilities.SetupLogging import setupLogging
logger = setupLogging()

# %%
from Devices.Coherent import CUBE

# %%
rm = pyvisa.ResourceManager()
device = CUBE(rm, address='ASRL3::INSTR')
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 rm = pyvisa.ResourceManager()
# ----> 2 device = CUBE(rm, address='ASRL3::INSTR')
#
# File ~\Desktop\instrumpy\Examples\Devices\../..\Devices\Coherent.py:52, in CoherentLaser.__init__(self, rm, address, config, maxOverride)
#      49 self.logger.debug("Logger initialized.")
#      51 # Set up serial communication
# ---> 52 self.device = rm.open_resource(address)
#      53 self.device.baud_rate = 19200
#      54 self.device.write_termination = "\r\n"
#
# File ~\.virtualenvs\instrumpy-kV3hxXJ6\Lib\site-packages\pyvisa\highlevel.py:3302, in ResourceManager.open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    3296     if not present:
#    3297         raise ValueError(
#    3298             "%r is not a valid attribute for type %s"
#    3299             % (key, res.__class__.__name__)
#    3300         )
# -> 3302 res.open(access_mode, open_timeout)
#    3304 for key, value in kwargs.items():
#    3305     setattr(res, key, value)
#
# File ~\.virtualenvs\instrumpy-kV3hxXJ6\Lib\site-packages\pyvisa\resources\resource.py:290, in Resource.open(self, access_mode, open_timeout)
#     286 logger.debug("%s - opening ...", self._resource_name, extra=self._logging_extra)
#     287 with self._resource_manager.ignore_warning(
#     288     constants.StatusCode.success_device_not_present
#     289 ):
# --> 290     self.session, status = self._resource_manager.open_bare_resource(
#     291         self._resource_name, access_mode, open_timeout
#     292     )
#     294     if status == constants.StatusCode.success_device_not_present:
#     295         # The device was not ready when we opened the session.
#     296         # Now it gets five seconds more to become ready.
#     297         # Every 0.1 seconds we probe it with viClear.
#     298         start_time = time.time()
#
# File ~\.virtualenvs\instrumpy-kV3hxXJ6\Lib\site-packages\pyvisa\highlevel.py:3227, in ResourceManager.open_bare_resource(self, resource_name, access_mode, open_timeout)
#    3198 def open_bare_resource(
#    3199     self,
#    3200     resource_name: str,
#    3201     access_mode: constants.AccessModes = constants.AccessModes.no_lock,
#    3202     open_timeout: int = constants.VI_TMO_IMMEDIATE,
#    3203 ) -> Tuple[VISASession, StatusCode]:
#    3204     """Open the specified resource without wrapping into a class.
#    3205
#    3206     Parameters
#    (...)   3225
#    3226     """
# -> 3227     return self.visalib.open(self.session, resource_name, access_mode, open_timeout)
#
# File ~\.virtualenvs\instrumpy-kV3hxXJ6\Lib\site-packages\pyvisa\ctwrapper\functions.py:1853, in open(library, session, resource_name, access_mode, open_timeout)
#    1849 out_session = ViSession()
#    1851 # [ViSession, ViRsrc, ViAccessMode, ViUInt32, ViPSession]
#    1852 # ViRsrc converts from (str, unicode, bytes) to bytes
# -> 1853 ret = library.viOpen(
#    1854     session, resource_name, access_mode, open_timeout, byref(out_session)
#    1855 )
#    1856 return out_session.value, ret
#
# File ~\.virtualenvs\instrumpy-kV3hxXJ6\Lib\site-packages\pyvisa\ctwrapper\highlevel.py:227, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     224         # Set session back to a safe value
#     225         session = None
# --> 227 return self.handle_return_value(session, ret_value)
#
# File ~\.virtualenvs\instrumpy-kV3hxXJ6\Lib\site-packages\pyvisa\highlevel.py:252, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     249     self._last_status_in_session[session] = rv
#     251 if rv < 0:
# --> 252     raise errors.VisaIOError(rv)
#     254 if rv in self.issue_warning_on:
#     255     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_SYSTEM_ERROR (-1073807360): Unknown system error (miscellaneous error).

# %%
device.power = 50

# %%
rm.list_resources()
# Out:
# ('ASRL3::INSTR', 'ASRL4::INSTR', 'GPIB1::14::INSTR')
