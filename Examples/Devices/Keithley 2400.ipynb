# %%
# Libraries
import pyvisa                    # Communication (also install pyvisa-py or NI VISA)
import matplotlib.pyplot as plt  # Plots
import numpy as np               # Maths
import pandas as pd              # DataFrames
import time                      # Delays
from tqdm.notebook import tqdm   # Progress bars (use 'for i in tqdm(iter)')
import os                        # Used for determining platform
import sys                       # Used for local import setup
sys.path.append(r"../../")       # Used for local imports

# %%
from Utilities.SetupLogging import setupLogging
logger = setupLogging()

# %%
from Devices.Keithley import SourceMeter2400

# %%
rm = pyvisa.ResourceManager()
device = SourceMeter2400(rm, sn='04085563')

# %%
device.addr
# Out:
# 'USB0::0x05E6::0x2450::04085563::INSTR'

# %%
device.device.query('*IDN?')
# Out:
# 'KEITHLEY INSTRUMENTS INC.,MODEL 2450,04085563,1.2.0f'

# %%
device.chime('success')

# %%
device.setCV(1, 1e-5)

# %%
#device.device.write(':SOUR:CLE:AUTO OFF')

# %%
device.on()

# %%
device.setCC(1e-3, 10)

# %%
device.V, device.I
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 device.V, device.I
#
# File ~\Desktop\instrumpy\Examples\Devices\../..\Devices\Keithley.py:166, in SourceMeter2400.getV(self)
#     165 def getV(self):
# --> 166     return float(self.device.query('MEAS:VOLT?'))
#
# File ~\.virtualenvs\instrumpy-kV3hxXJ6\Lib\site-packages\pyvisa\resources\messagebased.py:702, in MessageBasedResource.query(self, message, delay)
#     699 if delay > 0.0:
#     700     time.sleep(delay)
# --> 702 return self.read()
#
# File ~\.virtualenvs\instrumpy-kV3hxXJ6\Lib\site-packages\pyvisa\resources\messagebased.py:521, in MessageBasedResource.read(self, termination, encoding)
#     519 if termination is None:
#     520     termination = self._read_termination
# --> 521     message = self._read_raw().decode(enco)
#     522 else:
#     523     with self.read_termination_context(termination):
#
# File ~\.virtualenvs\instrumpy-kV3hxXJ6\Lib\site-packages\pyvisa\resources\messagebased.py:475, in MessageBasedResource._read_raw(self, size, monitoring_interface)
#     468 while status == loop_status:
#     469     logger.debug(
#     470         "%s - reading %d bytes (last status %r)",
#     471         self._resource_name,
#     472         size,
#     473         status,
#     474     )
# --> 475     chunk, status = self.visalib.read(self.session, size)
#     476     if monitoring_interface:
#     477         monitoring_interface.update(len(chunk))
#
# File ~\.virtualenvs\instrumpy-kV3hxXJ6\Lib\site-packages\pyvisa\ctwrapper\functions.py:2339, in read(library, session, count)
#    2337 buffer = create_string_buffer(count)
#    2338 return_count = ViUInt32()
# -> 2339 ret = library.viRead(session, buffer, count, byref(return_count))
#    2340 return buffer.raw[: return_count.value], ret
#
# File ~\.virtualenvs\instrumpy-kV3hxXJ6\Lib\site-packages\pyvisa\ctwrapper\highlevel.py:227, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     224         # Set session back to a safe value
#     225         session = None
# --> 227 return self.handle_return_value(session, ret_value)
#
# File ~\.virtualenvs\instrumpy-kV3hxXJ6\Lib\site-packages\pyvisa\highlevel.py:252, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     249     self._last_status_in_session[session] = rv
#     251 if rv < 0:
# --> 252     raise errors.VisaIOError(rv)
#     254 if rv in self.issue_warning_on:
#     255     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.
